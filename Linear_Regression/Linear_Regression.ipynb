# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# Define model and Loss

class Model(object):
    def __init__(self):
        self.W = tf.Variable(10.0)
        self.b = tf.Variable(-5.0)

    def __call__(self, inputs):
        return self.W * inputs + self.b

def compute_loss(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true-y_pred))

# %%
model = Model()

# Define True weight and bias

TRUE_W = 3.0
TRUE_b = 2.0

# Obtain training data, Let's synthesize the training data with some noise.

NUM_EXAMPLES = 1000
inputs  = tf.random.normal(shape=[NUM_EXAMPLES])
noise   = tf.random.normal(shape=[NUM_EXAMPLES])
outputs = inputs * TRUE_W + TRUE_b + noise

# %%
# Before we train the model let's visualize where the model stands right now.
# We'll plot the model's predictions in red and the training data in blue.

def plot(epoch):
    plt.scatter(inputs, outputs, c='b')
    plt.scatter(inputs, model(inputs), c='r')
    plt.title("epoch %2d, loss = %s" %(epoch, str(compute_loss(outputs, model(inputs)).numpy())))
    plt.legend()
    plt.draw()
    plt.ion()   # replacing plt.show()
    plt.pause(1)
    plt.close()

# %%
learning_rate = 0.1
for epoch in range(30):
    with tf.GradientTape() as tape:
        loss = compute_loss(outputs, model(inputs))

    dW, db = tape.gradient(loss, [model.W, model.b])

    model.W.assign_sub(learning_rate * dW)
    model.b.assign_sub(learning_rate * db)

    print("=> epoch %2d: w_true= %.2f, w_pred= %.2f; b_true= %.2f, b_pred= %.2f, loss= %.2f" %(
          epoch+1, TRUE_W, model.W.numpy(), TRUE_b, model.b.numpy(), loss.numpy()))
    plot(epoch + 1)
# Out:
# No handles with labels found to put in legend.
# => epoch  1: w_true= 3.00, w_pred= 8.57; b_true= 2.00, b_pred= -3.60, loss= 100.47
# No handles with labels found to put in legend.
# => epoch  2: w_true= 3.00, w_pred= 7.43; b_true= 2.00, b_pred= -2.47, loss= 64.40
# No handles with labels found to put in legend.
# => epoch  3: w_true= 3.00, w_pred= 6.53; b_true= 2.00, b_pred= -1.58, loss= 41.41
# No handles with labels found to put in legend.
# => epoch  4: w_true= 3.00, w_pred= 5.80; b_true= 2.00, b_pred= -0.86, loss= 26.76
# No handles with labels found to put in legend.
# => epoch  5: w_true= 3.00, w_pred= 5.23; b_true= 2.00, b_pred= -0.28, loss= 17.43
# No handles with labels found to put in legend.
# => epoch  6: w_true= 3.00, w_pred= 4.77; b_true= 2.00, b_pred= 0.18, loss= 11.48
# No handles with labels found to put in legend.
# => epoch  7: w_true= 3.00, w_pred= 4.41; b_true= 2.00, b_pred= 0.55, loss= 7.69
# No handles with labels found to put in legend.
# => epoch  8: w_true= 3.00, w_pred= 4.12; b_true= 2.00, b_pred= 0.85, loss= 5.27
# No handles with labels found to put in legend.
# => epoch  9: w_true= 3.00, w_pred= 3.89; b_true= 2.00, b_pred= 1.08, loss= 3.73
# No handles with labels found to put in legend.
# => epoch 10: w_true= 3.00, w_pred= 3.70; b_true= 2.00, b_pred= 1.27, loss= 2.75
# No handles with labels found to put in legend.
# => epoch 11: w_true= 3.00, w_pred= 3.56; b_true= 2.00, b_pred= 1.42, loss= 2.12
# No handles with labels found to put in legend.
# => epoch 12: w_true= 3.00, w_pred= 3.44; b_true= 2.00, b_pred= 1.54, loss= 1.73
# No handles with labels found to put in legend.
# => epoch 13: w_true= 3.00, w_pred= 3.35; b_true= 2.00, b_pred= 1.64, loss= 1.47
# No handles with labels found to put in legend.
# => epoch 14: w_true= 3.00, w_pred= 3.27; b_true= 2.00, b_pred= 1.72, loss= 1.31
# No handles with labels found to put in legend.
# => epoch 15: w_true= 3.00, w_pred= 3.22; b_true= 2.00, b_pred= 1.78, loss= 1.21
# No handles with labels found to put in legend.
# => epoch 16: w_true= 3.00, w_pred= 3.17; b_true= 2.00, b_pred= 1.83, loss= 1.14
# No handles with labels found to put in legend.
# => epoch 17: w_true= 3.00, w_pred= 3.13; b_true= 2.00, b_pred= 1.87, loss= 1.10
# No handles with labels found to put in legend.
# => epoch 18: w_true= 3.00, w_pred= 3.10; b_true= 2.00, b_pred= 1.90, loss= 1.07
# No handles with labels found to put in legend.
# => epoch 19: w_true= 3.00, w_pred= 3.08; b_true= 2.00, b_pred= 1.93, loss= 1.05
# No handles with labels found to put in legend.
# => epoch 20: w_true= 3.00, w_pred= 3.06; b_true= 2.00, b_pred= 1.95, loss= 1.04
# No handles with labels found to put in legend.
# => epoch 21: w_true= 3.00, w_pred= 3.04; b_true= 2.00, b_pred= 1.96, loss= 1.04
# No handles with labels found to put in legend.
# => epoch 22: w_true= 3.00, w_pred= 3.03; b_true= 2.00, b_pred= 1.98, loss= 1.03
# No handles with labels found to put in legend.
# => epoch 23: w_true= 3.00, w_pred= 3.02; b_true= 2.00, b_pred= 1.99, loss= 1.03
# No handles with labels found to put in legend.
# => epoch 24: w_true= 3.00, w_pred= 3.02; b_true= 2.00, b_pred= 2.00, loss= 1.03
# No handles with labels found to put in legend.
# => epoch 25: w_true= 3.00, w_pred= 3.01; b_true= 2.00, b_pred= 2.00, loss= 1.03
# No handles with labels found to put in legend.
# => epoch 26: w_true= 3.00, w_pred= 3.00; b_true= 2.00, b_pred= 2.01, loss= 1.03
# No handles with labels found to put in legend.
# => epoch 27: w_true= 3.00, w_pred= 3.00; b_true= 2.00, b_pred= 2.01, loss= 1.03
# No handles with labels found to put in legend.
# => epoch 28: w_true= 3.00, w_pred= 3.00; b_true= 2.00, b_pred= 2.02, loss= 1.03
# No handles with labels found to put in legend.
# => epoch 29: w_true= 3.00, w_pred= 3.00; b_true= 2.00, b_pred= 2.02, loss= 1.02
# No handles with labels found to put in legend.
# => epoch 30: w_true= 3.00, w_pred= 2.99; b_true= 2.00, b_pred= 2.02, loss= 1.02
