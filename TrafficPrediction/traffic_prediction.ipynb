# %%
import os

# %%
os.chdir('/home/user/ai/TrafficPrediction')

# %%
import visualize_dataset

# %%
import pickle

# %%
with open('train-well/test_loader',"rb") as f:
    test_loader_f = pickle.load(f)
with open('train-well/all_y_true',"rb") as f:
    all_y_true_f = pickle.load(f)
with open('train-well/all_predict_values',"rb") as f:
    all_predict_values_f = pickle.load(f)

# %%
visualize_dataset.show_pred(test_loader_f, all_y_true_f.cpu(), all_predict_values_f)
# Out:
# ChebNet基于原始值的精度指标  mae: 20.0642, rmse: 30.9966, mape: 0.0905
# GCN基于原始值的精度指标  mae: 32.3521, rmse: 48.0349, mape: 0.1254
# GAT基于原始值的精度指标  mae: 32.5398, rmse: 48.1079, mape: 0.1261
